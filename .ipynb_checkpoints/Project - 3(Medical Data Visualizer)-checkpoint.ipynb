# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
data = pd.read_csv('data/medical_examination.csv')

# %%
data.head()
# Out:
#    id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393    2     168    62.0    110     80            1     1      0
# 1   1  20228    1     156    85.0    140     90            3     1      0
# 2   2  18857    1     165    64.0    130     70            3     1      0
# 3   3  17623    2     169    82.0    150    100            1     1      0
# 4   4  17474    1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
data[data['overweight'] ==1]
# Out:
# Empty DataFrame
# Columns: [id, age, sex, height, weight, ap_hi, ap_lo, cholesterol, gluc, smoke, alco, active, cardio, BMI, overweight]
# Index: []

# %%
data['height (in m)'] = data['height']*0.01

# %%
data.head()
# Out:
#    id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393    2     168    62.0    110     80            1     1      0
# 1   1  20228    1     156    85.0    140     90            3     1      0
# 2   2  18857    1     165    64.0    130     70            3     1      0
# 3   3  17623    2     169    82.0    150    100            1     1      0
# 4   4  17474    1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio        BMI overweight
# 0     0       1       0  21.967120          0
# 1     0       1       1  34.927679          1
# 2     0       0       1  23.507805          0
# 3     0       1       1  28.710479          1
# 4     0       0       0  23.011177          0

# %%
#data['height'] = data['height'].apply(lambda x: float(x))
#data['height'].pow(1./2)
data['BMI'] = data['weight']/(data['height']*0.01).pow(2)
#data['BMI']
data['overweight'] = ''
for row_value in range(0,len(data)):
    if data['BMI'][row_value] > 25:
        data['overweight'][row_value] = 1
    else:
        data['overweight'][row_value] = 0
data['overweight']
# Out:
# C:\Users\DATASC~1\AppData\Local\Temp/ipykernel_2828/2595995386.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['overweight'][row_value] = 0
# C:\Users\DATASC~1\AppData\Local\Temp/ipykernel_2828/2595995386.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['overweight'][row_value] = 1
# 0        0
# 1        1
# 2        0
# 3        1
# 4        0
#         ..
# 69995    1
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: overweight, Length: 70000, dtype: object

# %%
a = pd.DataFrame([2,3,4], columns=['A'])
print(a)
print(len(a))
a['B'] =''
for i in range(0, len(a)):
    if a['A'][i] >2:
        print(a['A'][i])
        print('--')
        a['B'][i] ='S'
# a['A'][0]
print(a)
# Out:
#    A
# 0  2
# 1  3
# 2  4
# 3
# 3
# --
# 4
# --
#    A  B
# 0  2
# 1  3  S
# 2  4  S
# C:\Users\DATASC~1\AppData\Local\Temp/ipykernel_2828/25615846.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['B'][i] ='S'

# %%
a = pd.DataFrame([2,3,4], columns=['A'])
for i in range(0,len(a)):
    #print(i)
    print(a['A'][i])
# Out:
# 2
# 3
# 4

# %%
data.describe()
# Out:
#                  id           age           sex        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349843    164.359229     74.205690
# std    28851.302323   2467.251667      0.477253      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      3.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   sex          70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
a = 10
print(a)
a = float(a)
print(type(a))
# Out:
# 10
# <class 'float'>

# %%
5/1
# Out:
# 5.0
